# %%
from PIL import Image

# %%
mac=Image.open('empsec.png')

# %%
mac
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=220x165 at 0x15D92B0B488>

# %%
type(mac)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
mac
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=220x165 at 0x15D92B0B488>

# %%
mac.size
# Out:
# (220, 165)

# %%
mac.filename
# Out:
# 'empsec.png'

# %%
#cropping image

# %%
mac.crop()
# Out:
# <PIL.Image.Image image mode=RGBA size=220x165 at 0x15D92B183C8>

# %%
mac.crop((0,0,100,100))
# Out:
# <PIL.Image.Image image mode=RGBA size=100x100 at 0x15D92B1DA08>

# %%
mac.size
# Out:
# (220, 165)

# %% [markdown]
# halfway=220/2

# %%
mac.size
halfway=220/2
x=halfway -200
w=halfway +200
y=30
h=60

mac.crop((x,y,w,h))
# Out:
# <PIL.Image.Image image mode=RGBA size=400x30 at 0x15D92B1D888>

# %%
mac.size
# Out:
# (220, 165)

# %%
mac
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=220x165 at 0x15D92B0B488>

# %%
mac.resize((100,100))
# Out:
# <PIL.Image.Image image mode=RGBA size=100x100 at 0x15D93B2ACC8>

# %%
mac.rotate(90)
# Out:
# <PIL.Image.Image image mode=RGBA size=220x165 at 0x15D92B1D988>

# %% [raw]
# mac.rotate(-90)

# %%
mac.rotate(180)
# Out:
# <PIL.Image.Image image mode=RGBA size=220x165 at 0x15D93B34208>

# %%
mac.rotate(270)
# Out:
# <PIL.Image.Image image mode=RGBA size=220x165 at 0x15D93B34548>

# %%
mac.rotate(360)
# Out:
# <PIL.Image.Image image mode=RGBA size=220x165 at 0x15D93B34E88>

# %%
red=Image.open('red_color.png')

# %%
red
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=300x168 at 0x15D93B38548>

# %%
blue=Image.open('blue_color.png')

# %%
blue
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=300x168 at 0x15D93B39C08>

# %%
blue=Image.open('blue_color.png')

# %%
blue
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=300x168 at 0x15D92B1EB48>
